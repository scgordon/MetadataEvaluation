# %%
import pandas as pd
Dialect="EML"
dialectOccurrenceDF = pd.read_csv('../scripts/dialectContains.csv')
dialectOccurrenceDF=dialectOccurrenceDF[dialectOccurrenceDF['Concept']==Dialect]
FILLvalues=dialectOccurrenceDF.to_dict('records')
FILLvalues=FILLvalues[0]

# %%
FILLvalues
# Out:
# {'Abstract': 0,
#  'Acknowledgement': -1,
#  'Additional Attributes': -1,
#  'Additional Attributes - Content Information': -1,
#  'Additional Attributes - Descriptive Keywords': -1,
#  'Additional Attributes - Geographic Identifier': -1,
#  'Additional Attributes - Instrument': -1,
#  'Additional Attributes - Platform': -1,
#  'Additional Attributes - Quality Information': -1,
#  'Additional Lineage Documentation': -1,
#  'Additional Resource Documentation': -1,
#  'Additional Usage Documentation': -1,
#  'Address': -1,
#  'Algorithm Citation': -1,
#  'Alternate Metadata Citation': -1,
#  'Alternate Resource Title': -1,
#  'Ancillary Keyword': -1,
#  'Application Schema Information': -1,
#  'AssociatedDIFs': -1,
#  'Association': -1,
#  'Attribute Accuracy Explanation': -1,
#  'Attribute Accuracy Report': -1,
#  'Attribute Accuracy Value': -1,
#  'Attribute Constraints': 0,
#  'Attribute Definition': 0,
#  'Attribute Definition Source': -1,
#  'Attribute Label': -1,
#  'Attribute List': 0,
#  'Author': 0,
#  'Author / Originator': 0,
#  'Author / Originator Email Address': 0,
#  'Author / Originator Identifier': 0,
#  'Author / Originator Identifier Type': 0,
#  'Author / Originator World Wide Web Address': 0,
#  'Award Link': -1,
#  'Binding': -1,
#  'Bounding Box': 0,
#  'Bounding Polygon': -1,
#  'Browse Description': -1,
#  'Browse File Name': -1,
#  'Browse File Size': -1,
#  'Browse Format': -1,
#  'Browse URL': -1,
#  'Caption': -1,
#  'Center Latitude': -1,
#  'Center Longitude': -1,
#  'Cited Resource Alternate Title': -1,
#  'Cited Resource Identifier': -1,
#  'Cited Resource Title': -1,
#  'City': -1,
#  'Cloud Cover': -1,
#  'Codeset Domain Codeset Name': -1,
#  'Codeset Domain Codeset Source': -1,
#  'Collection Data Type': -1,
#  'Common Data Model Datatype': -1,
#  'Complete Citation': -1,
#  'Completeness Report': -1,
#  'Concept': 'EML',
#  'Confidence': -1,
#  'Conformance Result': -1,
#  'Constraint Reference': -1,
#  'Contact Instructions': -1,
#  'Contributor Name': 0,
#  'Contributor Role': 0,
#  'Coordinate Reference System (CRS)': 0,
#  'Country': -1,
#  'Coupled Resource': -1,
#  'Coupled Type': -1,
#  'Coverage Content Type': -1,
#  'Coverage Result': -1,
#  'Data Dates': -1,
#  'Data Quality Scope': -1,
#  'DataType': -1,
#  'Date Type': -1,
#  'DayNightFlag': -1,
#  'Descriptive Result': -1,
#  'Dimensions': -1,
#  'DimensionsName': -1,
#  'Distribution Contact': 0,
#  'Distribution Format': 0,
#  'Distribution Liability': -1,
#  'Easternmost Longitude': 0,
#  'Editor': -1,
#  'Email': -1,
#  'Embargo Date': -1,
#  'End Time': 0,
#  'Ends at Present Flag': -1,
#  'Entity Type Definition': 0,
#  'Entity Type Definition Source': -1,
#  'Entity Type Label': -1,
#  'Entity and Attribute Information': 0,
#  'Enumerated Domain Value': -1,
#  'Enumerated Domain Value Definition': -1,
#  'Enumerated Domain Value Definition Source': -1,
#  'Evaluation Method Description': -1,
#  'Evaluation Procedure': -1,
#  'Evaluation Reference': -1,
#  'Evaluation Reference Document': -1,
#  'Evaluation Specification': -1,
#  'Evalulation Method': -1,
#  'Evalulation Method Type': -1,
#  'Exclusion GRing Flag': -1,
#  'Fax': -1,
#  'Feature Catalogue Citation': -1,
#  'FillValue': -1,
#  'First Name': -1,
#  'Format Citation': -1,
#  'Format of the Online Resource': -1,
#  'Future Metadata Review Date': -1,
#  'GRing Point Latitude': -1,
#  'GRing Point Longitude': -1,
#  'GRing Point Sequence Number': -1,
#  'Geographic Description': -1,
#  'Grid Dimension Count': -1,
#  'Grid Dimension Resolution': -1,
#  'Grid Dimension Type Code': -1,
#  'Homogeneity': -1,
#  'Horizontal Positional Accuracy Explanation': -1,
#  'Horizontal Positional Accuracy Report': -1,
#  'Horizontal Positional Accuracy Value': -1,
#  'Host Project Identifier': -1,
#  'Hours of Service': -1,
#  'ISBN': -1,
#  'ISSN': -1,
#  'Identified Issues Citation': -1,
#  'Input Granule': -1,
#  'Instrument': 0,
#  'Instrument Characteristics': -1,
#  'Instrument Characteristics Data Type': -1,
#  'Instrument Characteristics Description': -1,
#  'Instrument Characteristics Name': -1,
#  'Instrument Characteristics Unit': -1,
#  'Instrument Characteristics Value': -1,
#  'Instrument Citation': -1,
#  'Instrument Description': -1,
#  'Instrument Keyword': -1,
#  'Instrument Keyword Vocabulary': -1,
#  'Instrument Long Name': -1,
#  'Instrument Operation Modes': -1,
#  'Instrument Short Name': -1,
#  'Instrument Type': -1,
#  'Instrument UUID': -1,
#  'Interface': -1,
#  'Issue': -1,
#  'Issue Date': -1,
#  'Keyword': 0,
#  'Keyword Ontology Citation': -1,
#  'Keyword Type': 0,
#  'Keyword Vocabulary': 0,
#  'Keyword Vocabulary Citation': -1,
#  'Last Name': -1,
#  'Latitude Dimension Length': -1,
#  'Latitude Resolution': -1,
#  'Lineage Scope': -1,
#  'Lineage Statement': -1,
#  'Local Version Identifier': -1,
#  'Logical Consistency': -1,
#  'Logical Consistency Report': -1,
#  'LongName': -1,
#  'Longitude Dimension Length': -1,
#  'Longitude Resolution': -1,
#  'Maintenance': 0,
#  'Measure': -1,
#  'Measure Description': -1,
#  'Measure Identifier': -1,
#  'Measure Name': -1,
#  'Measure Source Citation': -1,
#  'Measure Time': -1,
#  'Media': 0,
#  'Medium Reference': -1,
#  'Metadata Access Constraints': 0,
#  'Metadata Association': -1,
#  'Metadata Contact': 0,
#  'Metadata Dates': -1,
#  'Metadata Deletion Date': -1,
#  'Metadata Identifier': 0,
#  'Metadata Language': -1,
#  'Metadata Modified Date': 0,
#  'Metadata Profile Citation': -1,
#  'Metadata Standard Citation': -1,
#  'Metadata Standard Version': -1,
#  'Metadata Time Convention': -1,
#  'Metadata Use Constraints': 0,
#  'Middle Name': -1,
#  'Name': -1,
#  'Naming Authority': -1,
#  'Northernmost Latitude': 0,
#  'Offset': -1,
#  'Online Resource': 0,
#  'Online Resource Description': -1,
#  'Online Resource Function': -1,
#  'Online Resource Name/Title': -1,
#  'Operation Citation': -1,
#  'Ordering Instructions': 0,
#  'Organization Name': 0,
#  'Originating Organization': 0,
#  'Other Citation Details': -1,
#  'Overview': -1,
#  'Overview Citation': -1,
#  'PGE Name': -1,
#  'PGE Version': -1,
#  'Pages': -1,
#  'Paleo Temporal Coverage': 0,
#  'Parameter Definition': -1,
#  'Parameter Name': -1,
#  'Parameter Name (Long)': -1,
#  'Parameter Name (Standard)': -1,
#  'Parameter Units': -1,
#  'Parameters Citation': -1,
#  'Parent Identifier': 0,
#  'Parent Metadata Reference': -1,
#  'Party': -1,
#  'Phone': -1,
#  'Phone Type': -1,
#  'Place Keyword': 0,
#  'Place Keyword Vocabulary': -1,
#  'Plan Citation': -1,
#  'Platform': -1,
#  'Platform Characteristics': -1,
#  'Platform Characteristics Data Type': -1,
#  'Platform Characteristics Description': -1,
#  'Platform Characteristics Name': -1,
#  'Platform Characteristics Unit': -1,
#  'Platform Characteristics Value': -1,
#  'Platform Citation': -1,
#  'Platform Description': -1,
#  'Platform Keyword': -1,
#  'Platform Keyword Vocabulary': -1,
#  'Platform Long Name': -1,
#  'Platform Orbit Information': -1,
#  'Platform Short Name': -1,
#  'Platform Sponsor': -1,
#  'Platform Type': -1,
#  'Platform UUID': -1,
#  'Point Latitude': -1,
#  'Point Longitude': -1,
#  'Portrayal Catalogue Citation': -1,
#  'Position Name': -1,
#  'Positional Accuracy Report': -1,
#  'Postal_Code': -1,
#  'Precision of Seconds': -1,
#  'Presentation Form': -1,
#  'Process Step': 0,
#  'Process Step Description': -1,
#  'Process Step Purpose': -1,
#  'Process Step Reference': -1,
#  'Process Step Scope': -1,
#  'Process Step Time': -1,
#  'Processing Citation': -1,
#  'Processing Level': -1,
#  'Processing Software Reference': -1,
#  'Processor': -1,
#  'Producer Identifier': -1,
#  'Product Link': -1,
#  'Project Contact': -1,
#  'Project Description': 0,
#  'Project Host': -1,
#  'Project Keyword': -1,
#  'Project Name': 0,
#  'Project Sponsor': -1,
#  'Project Website Link': -1,
#  'Province or State': -1,
#  'Publication Date': 0,
#  'Publication Information': -1,
#  'Publisher': 0,
#  'Publisher E-Mail': 0,
#  'Publisher Location': -1,
#  'Publisher URL': 0,
#  'Purpose': 0,
#  'Quality Statement': 0,
#  'Quantitative Result': -1,
#  'Radius Units': -1,
#  'Range Domain Attribute Resolution': -1,
#  'Range Domain Maximum Value': -1,
#  'Range Domain Minimum Value': -1,
#  'Range Domain Units': -1,
#  'Related Metadata Citation': -1,
#  'Related Resource Citation': 0,
#  'Related Resource Identifier': 0,
#  'Related URL': -1,
#  'Release Constraints': -1,
#  'Report': -1,
#  'Report Number': -1,
#  'Representativity': -1,
#  'Reprocessing Plan Note': -1,
#  'Requirement Citation': -1,
#  'Resource Access Constraints': 0,
#  'Resource Citation': 0,
#  'Resource Contact': 0,
#  'Resource Cost or Fees': -1,
#  'Resource Creation Date': -1,
#  'Resource Creation/Revision Date': 0,
#  'Resource Distribution': 0,
#  'Resource Format': 0,
#  'Resource Identifier': 0,
#  'Resource Identifier Type': 0,
#  'Resource Language': 0,
#  'Resource Lineage': 0,
#  'Resource Long Name': 0,
#  'Resource Quality Description': 0,
#  'Resource Revision Date': 0,
#  'Resource Status': 0,
#  'Resource Title': 0,
#  'Resource Type': 0,
#  'Resource Update Frequency': 0,
#  'Resource Use Constraints': 0,
#  'Resource Version': -1,
#  'Resource on-line Link': 0,
#  'Responsibility': -1,
#  'Responsible Party Identifier': 0,
#  'Responsible Party Identifier Type': 0,
#  'Responsible Party Identifier Type URI': -1,
#  'Result': -1,
#  'Rights': 0,
#  'Role': -1,
#  'Scale': -1,
#  'Security Constraints': 0,
#  'Sensor Characteristics': -1,
#  'Sensor Characteristics Name': -1,
#  'Sensor Characteristics Value': -1,
#  'Sensor Long Name': -1,
#  'Sensor Short Name': -1,
#  'Series Title': -1,
#  'Service': -1,
#  'Service Location': -1,
#  'Service Operation Name': -1,
#  'Service Operation Reference': -1,
#  'Service Parameters': -1,
#  'Service Profile Reference': -1,
#  'Service Provider': -1,
#  'Service Resource Reference': -1,
#  'Service Standard Citation': -1,
#  'Service Type': -1,
#  'Service Type Version': -1,
#  'Site': -1,
#  'Site Location': -1,
#  'Source': -1,
#  'Source Citation': -1,
#  'Source Citation Abbreviation': -1,
#  'Source Description': -1,
#  'Source Metadata': -1,
#  'Source Reference System': -1,
#  'Source Scope': -1,
#  'Source Step': -1,
#  'Source Time Period': -1,
#  'Source Used': -1,
#  'Southernmost Latitude': 0,
#  'Spatial Extent': 0,
#  'Spatial Representation': -1,
#  'Spatial Resolution': 0,
#  'Specific Usage': -1,
#  'Sponsor Project Identifier': -1,
#  'Standalone Report Citation': -1,
#  'Standard Name Vocabulary': -1,
#  'Start Time': 0,
#  'Supplemental Information': 0,
#  'Table of Contents': -1,
#  'Taxonomic Extent': 0,
#  'Temporal Extent': 0,
#  'Temporal Keyword': -1,
#  'Temporal Quality Report': -1,
#  'Temporal Range Type': -1,
#  'Temporal Resolution': 0,
#  'Thematic Accuracy Report': -1,
#  'Theme Keyword': 0,
#  'Time Type': -1,
#  'Topic Category': -1,
#  'Transfer Size': 0,
#  'TwoDCoordinateSystem': -1,
#  'Types': -1,
#  'URL': -1,
#  'Units': -1,
#  'Unrepresentable Domain': -1,
#  'Usability Report': -1,
#  'Usage Time': -1,
#  'User Contact': -1,
#  'User Determined Limitations': -1,
#  'User Response': -1,
#  'ValidRange': -1,
#  'VariableType': -1,
#  'Version Date': -1,
#  'Version Description': -1,
#  'Vertical Dimension Length': -1,
#  'Vertical Extent': 0,
#  'Vertical Maximum': 0,
#  'Vertical Minimum': 0,
#  'Vertical Positional Accuracy Explanation': -1,
#  'Vertical Positional Accuracy Report': -1,
#  'Vertical Positional Accuracy Value': -1,
#  'Vertical Resolution': 0,
#  'Volume': -1,
#  'Web Page': -1,
#  'Westernmost Longitude': 0}

# %%
dialectOccurrenceDF=dialectOccurrenceDF.reset_index()
dialectOccurrenceDF
# Out:
#    index Concept  Abstract  Acknowledgement  Additional Attributes  \
# 0     12     EML         0               -1                     -1
#
#    Additional Attributes - Content Information  \
# 0                                           -1
#
#    Additional Attributes - Descriptive Keywords  \
# 0                                            -1
#
#    Additional Attributes - Geographic Identifier  \
# 0                                             -1
#
#    Additional Attributes - Instrument  Additional Attributes - Platform  \
# 0                                  -1                                -1
#
#            ...            Vertical Extent  Vertical Maximum  Vertical Minimum  \
# 0          ...                          0                 0                 0
#
#    Vertical Positional Accuracy Explanation  \
# 0                                        -1
#
#    Vertical Positional Accuracy Report  Vertical Positional Accuracy Value  \
# 0                                   -1                                  -1
#
#    Vertical Resolution  Volume  Web Page  Westernmost Longitude
# 0                    0      -1        -1                      0
#
# [1 rows x 394 columns]

# %%
dialectOccurrenceDF.drop(dialectOccurrenceDF.index[0])
# Out:
# Empty DataFrame
# Columns: [index, Concept, Abstract, Acknowledgement, Additional Attributes, Additional Attributes - Content Information, Additional Attributes - Descriptive Keywords, Additional Attributes - Geographic Identifier, Additional Attributes - Instrument, Additional Attributes - Platform, Additional Attributes - Quality Information, Additional Lineage Documentation, Additional Resource Documentation, Additional Usage Documentation, Address, Algorithm Citation, Alternate Metadata Citation, Alternate Resource Title, Ancillary Keyword, Application Schema Information, AssociatedDIFs, Association, Attribute Accuracy Explanation, Attribute Accuracy Report, Attribute Accuracy Value, Attribute Constraints, Attribute Definition, Attribute Definition Source, Attribute Label, Attribute List, Author, Author / Originator, Author / Originator Email Address, Author / Originator Identifier, Author / Originator Identifier Type, Author / Originator World Wide Web Address, Award Link, Binding, Bounding Box, Bounding Polygon, Browse Description, Browse File Name, Browse File Size, Browse Format, Browse URL, Caption, Center Latitude, Center Longitude, Cited Resource Alternate Title, Cited Resource Identifier, Cited Resource Title, City, Cloud Cover, Codeset Domain Codeset Name, Codeset Domain Codeset Source, Collection Data Type, Common Data Model Datatype, Complete Citation, Completeness Report, Confidence, Conformance Result, Constraint Reference, Contact Instructions, Contributor Name, Contributor Role, Coordinate Reference System (CRS), Country, Coupled Resource, Coupled Type, Coverage Content Type, Coverage Result, Data Dates, Data Quality Scope, DataType, Date Type, DayNightFlag, Descriptive Result, Dimensions, DimensionsName, Distribution Contact, Distribution Format, Distribution Liability, Easternmost Longitude, Editor, Email, Embargo Date, End Time, Ends at Present Flag, Entity Type Definition, Entity Type Definition Source, Entity Type Label, Entity and Attribute Information, Enumerated Domain Value, Enumerated Domain Value Definition, Enumerated Domain Value Definition Source, Evaluation Method Description, Evaluation Procedure, Evaluation Reference, Evaluation Reference Document, Evaluation Specification, ...]
# Index: []
#
# [0 rows x 394 columns]
