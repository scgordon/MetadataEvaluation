# %% [markdown]
# ### This notebook allows the user to evaluate the structure and content of valid XML metadata using the metadataEvaluation Python module.
#
#
# * Content for a selectable element is viewable
#
# * Consistency across elements is checked
#
# * Occurrence is compared through time
#
# * Records missing a selectable element are listed

# %%
# This cell imports modules and defines functions used to set variables and functions 
# that create dataframes of data products that can be saved to a csv

# modules to support functions
import pandas as pd
from ipywidgets import *
import ipywidgets as widgets
from IPython.display import display
import metadataEvaluation

#functions to identify and label an xml collection for Metadata Evaluation
def OrganizationChoices(organization):
    global Organization
    Organization=organization
    print("Curating Organization", Organization)
    
def CollectionName(collection):
    global Collection
    Collection=collection
    print("Collection is named", Collection)
    
def DialectName(dialect):
    global Dialect
    Dialect=dialect
    print("Collection is written in the", Dialect,"dialect")   
    
def metadataLocation(directory):
    global MetadataLocation
    MetadataLocation=directory
    print("The local directory", MetadataLocation,"contains the metadata for evaluation")   
    
    
#Create a dropdown that allows multiple selection using command and click with the mouse 
#or arrow keys to select additional individual data tables, or 
#shift with the mouse to select each choice between the two clicked.

#Creates a list of all the paths to evaluated collection data.
EvaluatedMetadata=[]
for dirpath, dirnames, filenames in os.walk("../data"):
    for filename in [f for f in filenames if '.csv' in f]:
        EvaluatedMetadata.extend([os.path.join(dirpath, filename)])

#widget for selecting multiple collections        
w6=widgets.SelectMultiple(
    options=sorted(EvaluatedMetadata),
    value=['../data/Sample/Sample_Sample_Evaluated.csv.gz'],
    #rows=10,
    description='Evaluated Data',
    disabled=False
)
#Show the widget

#widget for naming the file
w5=widgets.Text(
    value='',
    placeholder='Your file name (no spaces)',
    description='Name your File:',
    disabled=False
)
        
w=interactive(OrganizationChoices, organization='')    
w2=interactive(CollectionName, collection='')
w3=interactive(DialectName, dialect='')
w4=interactive(metadataLocation, directory='')

# %% [markdown]
# #### Now let's create the variables we will use for the functions needed from metadataEvaluation.py. If you change the text, the variable will change, no need to rerun the cell. This is helpful for creating data products from each lab

# %%
display(w)
display(w2)
display(w3)
display(w4)

# %% [markdown]
# ### Run this cell for each time to evaluate the collection and create data products using the variables in the widgets in the previous code cell. Remember you don't need to rerun the previous cell to change variables.

# %%
# XMLeval uploads a zip file to the webservice, and reads the return into a dataframe
EvaluatedMetadataDF=metadataEvaluation.XMLeval(MetadataLocation, Organization, Collection, Dialect)

# simpleXPathDataProduct clarifies the xpaths by removing namespaces and in the case of ISO 19115* dialects removes the ISO classes
EvaluatedMetadataDF=metadataEvaluation.fullXPathDataProduct(EvaluatedMetadataDF, Organization, Collection, Dialect)

# xpathOccurrence creates a pivot table of xpaths, record occurrence counts, occurrence percentages and average occurrences per record
xpathOccurrenceDF=metadataEvaluation.xpathOccurrence(EvaluatedMetadataDF, Organization, Collection, Dialect)

# XpathCounts creates a pivot table with each record a row and xpaths for the columns, with a record count
XpathCounts=metadataEvaluation.XpathCounts(EvaluatedMetadataDF, Organization, Collection, Dialect)
xpathOccurrenceDF
# Out:
#                                                 XPath       Collection  \
# 0                                   Number of Records  2018-02_Re3data
# 1                    /r3d:re3data/@xsi:schemaLocation  2018-02_Re3data
# 2      /r3d:re3data/r3d:repository/r3d:additionalName  2018-02_Re3data
# 3   /r3d:re3data/r3d:repository/r3d:additionalName...  2018-02_Re3data
# 4           /r3d:re3data/r3d:repository/r3d:aidSystem  2018-02_Re3data
# 5                 /r3d:re3data/r3d:repository/r3d:api  2018-02_Re3data
# 6        /r3d:re3data/r3d:repository/r3d:api/@apiType  2018-02_Re3data
# 7         /r3d:re3data/r3d:repository/r3d:certificate  2018-02_Re3data
# 8   /r3d:re3data/r3d:repository/r3d:citationGuidel...  2018-02_Re3data
# 9         /r3d:re3data/r3d:repository/r3d:contentType  2018-02_Re3data
# 10  /r3d:re3data/r3d:repository/r3d:contentType/@c...  2018-02_Re3data
# 11  /r3d:re3data/r3d:repository/r3d:dataAccess/r3d...  2018-02_Re3data
# 12  /r3d:re3data/r3d:repository/r3d:dataAccess/r3d...  2018-02_Re3data
# 13  /r3d:re3data/r3d:repository/r3d:dataLicense/r3...  2018-02_Re3data
# 14  /r3d:re3data/r3d:repository/r3d:dataLicense/r3...  2018-02_Re3data
# 15  /r3d:re3data/r3d:repository/r3d:dataUpload/r3d...  2018-02_Re3data
# 16  /r3d:re3data/r3d:repository/r3d:dataUpload/r3d...  2018-02_Re3data
# 17  /r3d:re3data/r3d:repository/r3d:dataUploadLice...  2018-02_Re3data
# 18  /r3d:re3data/r3d:repository/r3d:dataUploadLice...  2018-02_Re3data
# 19  /r3d:re3data/r3d:repository/r3d:databaseAccess...  2018-02_Re3data
# 20  /r3d:re3data/r3d:repository/r3d:databaseAccess...  2018-02_Re3data
# 21  /r3d:re3data/r3d:repository/r3d:databaseLicens...  2018-02_Re3data
# 22  /r3d:re3data/r3d:repository/r3d:databaseLicens...  2018-02_Re3data
# 23        /r3d:re3data/r3d:repository/r3d:description  2018-02_Re3data
# 24  /r3d:re3data/r3d:repository/r3d:description/@l...  2018-02_Re3data
# 25            /r3d:re3data/r3d:repository/r3d:endDate  2018-02_Re3data
# 26  /r3d:re3data/r3d:repository/r3d:enhancedPublic...  2018-02_Re3data
# 27          /r3d:re3data/r3d:repository/r3d:entryDate  2018-02_Re3data
# 28  /r3d:re3data/r3d:repository/r3d:institution/r3...  2018-02_Re3data
# 29  /r3d:re3data/r3d:repository/r3d:institution/r3...  2018-02_Re3data
# ..                                                ...              ...
# 39  /r3d:re3data/r3d:repository/r3d:institution/r3...  2018-02_Re3data
# 40            /r3d:re3data/r3d:repository/r3d:keyword  2018-02_Re3data
# 41         /r3d:re3data/r3d:repository/r3d:lastUpdate  2018-02_Re3data
# 42  /r3d:re3data/r3d:repository/r3d:metadataStanda...  2018-02_Re3data
# 43  /r3d:re3data/r3d:repository/r3d:metadataStanda...  2018-02_Re3data
# 44  /r3d:re3data/r3d:repository/r3d:metadataStanda...  2018-02_Re3data
# 45  /r3d:re3data/r3d:repository/r3d:missionStateme...  2018-02_Re3data
# 46          /r3d:re3data/r3d:repository/r3d:pidSystem  2018-02_Re3data
# 47  /r3d:re3data/r3d:repository/r3d:policy/r3d:pol...  2018-02_Re3data
# 48  /r3d:re3data/r3d:repository/r3d:policy/r3d:pol...  2018-02_Re3data
# 49       /r3d:re3data/r3d:repository/r3d:providerType  2018-02_Re3data
# 50  /r3d:re3data/r3d:repository/r3d:qualityManagement  2018-02_Re3data
# 51  /r3d:re3data/r3d:repository/r3d:re3data.orgIde...  2018-02_Re3data
# 52            /r3d:re3data/r3d:repository/r3d:remarks  2018-02_Re3data
# 53  /r3d:re3data/r3d:repository/r3d:repositoryContact  2018-02_Re3data
# 54  /r3d:re3data/r3d:repository/r3d:repositoryIden...  2018-02_Re3data
# 55  /r3d:re3data/r3d:repository/r3d:repositoryLang...  2018-02_Re3data
# 56     /r3d:re3data/r3d:repository/r3d:repositoryName  2018-02_Re3data
# 57  /r3d:re3data/r3d:repository/r3d:repositoryName...  2018-02_Re3data
# 58      /r3d:re3data/r3d:repository/r3d:repositoryURL  2018-02_Re3data
# 59               /r3d:re3data/r3d:repository/r3d:size  2018-02_Re3data
# 60      /r3d:re3data/r3d:repository/r3d:size/@updated  2018-02_Re3data
# 61  /r3d:re3data/r3d:repository/r3d:software/r3d:s...  2018-02_Re3data
# 62          /r3d:re3data/r3d:repository/r3d:startDate  2018-02_Re3data
# 63            /r3d:re3data/r3d:repository/r3d:subject  2018-02_Re3data
# 64  /r3d:re3data/r3d:repository/r3d:subject/@subje...  2018-02_Re3data
# 65        /r3d:re3data/r3d:repository/r3d:syndication  2018-02_Re3data
# 66  /r3d:re3data/r3d:repository/r3d:syndication/@s...  2018-02_Re3data
# 67               /r3d:re3data/r3d:repository/r3d:type  2018-02_Re3data
# 68         /r3d:re3data/r3d:repository/r3d:versioning  2018-02_Re3data
#
#     XPathCount  RecordCount AverageOccurrencePerRecord CollectionOccurrence%
# 0         2030         2030                       1.00               100.00%
# 1         2030         2030                       1.00               100.00%
# 2         2454         1663                       1.21                81.92%
# 3         1830         1663                       0.90                81.92%
# 4          388          380                       0.19                18.72%
# 5         1289          902                       0.63                44.43%
# 6         1253          903                       0.62                44.48%
# 7          215          184                       0.11                 9.06%
# 8         1180         1180                       0.58                58.13%
# 9         9365         2029                       4.61                99.95%
# 10        2029         2029                       1.00                99.95%
# 11        1338          977                       0.66                48.13%
# 12        3109         2026                       1.53                99.80%
# 13        2989         2029                       1.47                99.95%
# 14        3163         2029                       1.56                99.95%
# 15        1384         1257                       0.68                61.92%
# 16        2025         2012                       1.00                99.11%
# 17         585          552                       0.29                27.19%
# 18         585          553                       0.29                27.24%
# 19         114          110                       0.06                 5.42%
# 20        2030         2030                       1.00               100.00%
# 21         428          418                       0.21                20.59%
# 22         433          418                       0.21                20.59%
# 23        2029         2029                       1.00                99.95%
# 24        2030         2030                       1.00               100.00%
# 25          87           87                       0.04                 4.29%
# 26        2000         2000                       0.99                98.52%
# 27        2030         2030                       1.00               100.00%
# 28        6010         1827                       2.96                90.00%
# 29        2409         1827                       1.19                90.00%
# ..         ...          ...                        ...                   ...
# 39        4938         2030                       2.43               100.00%
# 40       15215         2030                       7.50               100.00%
# 41        2030         2030                       1.00               100.00%
# 42         853          606                       0.42                29.85%
# 43         606          606                       0.30                29.85%
# 44         847          606                       0.42                29.85%
# 45        1665         1665                       0.82                82.02%
# 46        2014         1929                       0.99                95.02%
# 47        3187         1784                       1.57                87.88%
# 48        3173         1784                       1.56                87.88%
# 49        2606         2025                       1.28                99.75%
# 50        2010         2010                       0.99                99.01%
# 51        2030         2030                       1.00               100.00%
# 52        1359         1359                       0.67                66.95%
# 53        2324         1757                       1.14                86.55%
# 54        1118          553                       0.55                27.24%
# 55        2742         2024                       1.35                99.70%
# 56        2030         2030                       1.00               100.00%
# 57        2030         2030                       1.00               100.00%
# 58        2030         2030                       1.00               100.00%
# 59         798          798                       0.39                39.31%
# 60        2030         2030                       1.00               100.00%
# 61        1708         1705                       0.84                83.99%
# 62        1435         1435                       0.71                70.69%
# 63       12108         2013                       5.96                99.16%
# 64        2013         2013                       0.99                99.16%
# 65         714          569                       0.35                28.03%
# 66         626          569                       0.31                28.03%
# 67        2428         2017                       1.20                99.36%
# 68         965          965                       0.48                47.54%
#
# [69 rows x 6 columns]

# %% [markdown]
# ### Combine the data to compare between collections

# %%
#Creates a list of all the paths to evaluated collection data.
EvaluatedMetadata=[]
for dirpath, dirnames, filenames in os.walk("../data"):
    for filename in [f for f in filenames if '.csv' in f]:
        EvaluatedMetadata.extend([os.path.join(dirpath, filename)])

#widget for selecting multiple collections        
w6=widgets.SelectMultiple(
    options=sorted(EvaluatedMetadata),
    value=['../data/Sample/Sample_Sample_Evaluated.csv.gz'],
    #rows=10,
    description='Evaluated Data',
    disabled=False
)
#Show the widget

#widget for naming the file
w5=widgets.Text(
    value='',
    placeholder='Your file name (no spaces)',
    description='Name your File:',
    disabled=False
)     
# Fill in variables then run the function below to combine the XPathOccurrence csv from each lab
display(w5)
display(w6)

# %% [markdown]
# ##### Combine XPath Counts csv from each lab for later exploration

# %%
# create variables and filepaths from the widget choices
CollectionComparisons=w6.value
DataDestination=os.path.join('../data/Combined', str(w5.value)+'.csv')
# run the function below to combine the XPathCounts csv from each lab
CombinedXPathCountsDF=metadataEvaluation.CombineXPathCounts(CollectionComparisons,DataDestination)

# %% [markdown]
# ##### Combine Evaluated csv from each lab for later exploration

# %%
# create variables and filepaths from the widget choices
CollectionComparisons=w6.value
DataDestination=os.path.join('../data/Combined', str(w5.value)+'.csv.gz')
# run the function below to combine the EvaluatedMetadata csv from each lab
CombinedEvaluatedMetadataDF=metadataEvaluation.CombineEvaluatedMetadata(CollectionComparisons, DataDestination)

# %% [markdown]
# ##### Combine XPath Occurrence csv from each lab to create an overview of the labs.

# %%
# create variables and filepaths from the widget choices
CollectionComparisons=w6.value
DataDestination=os.path.join('../data/Combined', str(w5.value)+'.csv')
# run function to combine selected xpathOccurrence data
CombinedXPathOccurrenceDF=metadataEvaluation.CombineXPathOccurrence(CollectionComparisons,DataDestination)
CombinedXPathOccurrenceDF
# Out:
#                                                 XPath 2017-11_Re3data  \
# 0                    /r3d:re3data/@xsi:schemaLocation         100.00%
# 1      /r3d:re3data/r3d:repository/r3d:additionalName          82.15%
# 2   /r3d:re3data/r3d:repository/r3d:additionalName...          82.15%
# 3           /r3d:re3data/r3d:repository/r3d:aidSystem          18.20%
# 4                 /r3d:re3data/r3d:repository/r3d:api          44.49%
# 5        /r3d:re3data/r3d:repository/r3d:api/@apiType          44.54%
# 6         /r3d:re3data/r3d:repository/r3d:certificate           8.85%
# 7   /r3d:re3data/r3d:repository/r3d:citationGuidel...          57.94%
# 8         /r3d:re3data/r3d:repository/r3d:contentType          99.95%
# 9   /r3d:re3data/r3d:repository/r3d:contentType/@c...          99.95%
# 10  /r3d:re3data/r3d:repository/r3d:dataAccess/r3d...          48.28%
# 11  /r3d:re3data/r3d:repository/r3d:dataAccess/r3d...          99.85%
# 12  /r3d:re3data/r3d:repository/r3d:dataLicense/r3...          99.95%
# 13  /r3d:re3data/r3d:repository/r3d:dataLicense/r3...          99.95%
# 14  /r3d:re3data/r3d:repository/r3d:dataUpload/r3d...          61.32%
# 15  /r3d:re3data/r3d:repository/r3d:dataUpload/r3d...          99.19%
# 16  /r3d:re3data/r3d:repository/r3d:dataUploadLice...          26.95%
# 17  /r3d:re3data/r3d:repository/r3d:dataUploadLice...          27.05%
# 18  /r3d:re3data/r3d:repository/r3d:databaseAccess...           5.31%
# 19  /r3d:re3data/r3d:repository/r3d:databaseAccess...         100.00%
# 20  /r3d:re3data/r3d:repository/r3d:databaseLicens...          20.68%
# 21  /r3d:re3data/r3d:repository/r3d:databaseLicens...          20.68%
# 22        /r3d:re3data/r3d:repository/r3d:description          99.95%
# 23  /r3d:re3data/r3d:repository/r3d:description/@l...         100.00%
# 24            /r3d:re3data/r3d:repository/r3d:endDate           3.99%
# 25  /r3d:re3data/r3d:repository/r3d:enhancedPublic...          97.98%
# 26          /r3d:re3data/r3d:repository/r3d:entryDate         100.00%
# 27  /r3d:re3data/r3d:repository/r3d:institution/r3...          90.09%
# 28  /r3d:re3data/r3d:repository/r3d:institution/r3...          90.09%
# 29  /r3d:re3data/r3d:repository/r3d:institution/r3...          87.56%
# ..                                                ...             ...
# 39            /r3d:re3data/r3d:repository/r3d:keyword         100.00%
# 40         /r3d:re3data/r3d:repository/r3d:lastUpdate         100.00%
# 41  /r3d:re3data/r3d:repository/r3d:metadataStanda...          28.67%
# 42  /r3d:re3data/r3d:repository/r3d:metadataStanda...          28.67%
# 43  /r3d:re3data/r3d:repository/r3d:metadataStanda...          28.67%
# 44  /r3d:re3data/r3d:repository/r3d:missionStateme...          81.19%
# 45          /r3d:re3data/r3d:repository/r3d:pidSystem          95.40%
# 46  /r3d:re3data/r3d:repository/r3d:policy/r3d:pol...          87.66%
# 47  /r3d:re3data/r3d:repository/r3d:policy/r3d:pol...          87.66%
# 48       /r3d:re3data/r3d:repository/r3d:providerType          99.75%
# 49  /r3d:re3data/r3d:repository/r3d:qualityManagement          98.43%
# 50  /r3d:re3data/r3d:repository/r3d:re3data.orgIde...         100.00%
# 51            /r3d:re3data/r3d:repository/r3d:remarks          67.85%
# 52  /r3d:re3data/r3d:repository/r3d:repositoryContact          85.19%
# 53  /r3d:re3data/r3d:repository/r3d:repositoryIden...          26.79%
# 54  /r3d:re3data/r3d:repository/r3d:repositoryLang...          99.65%
# 55     /r3d:re3data/r3d:repository/r3d:repositoryName         100.00%
# 56  /r3d:re3data/r3d:repository/r3d:repositoryName...         100.00%
# 57      /r3d:re3data/r3d:repository/r3d:repositoryURL          99.95%
# 58               /r3d:re3data/r3d:repository/r3d:size          38.83%
# 59      /r3d:re3data/r3d:repository/r3d:size/@updated         100.00%
# 60  /r3d:re3data/r3d:repository/r3d:software/r3d:s...          83.82%
# 61          /r3d:re3data/r3d:repository/r3d:startDate          71.08%
# 62            /r3d:re3data/r3d:repository/r3d:subject          99.14%
# 63  /r3d:re3data/r3d:repository/r3d:subject/@subje...          99.14%
# 64        /r3d:re3data/r3d:repository/r3d:syndication          28.36%
# 65  /r3d:re3data/r3d:repository/r3d:syndication/@s...          28.36%
# 66               /r3d:re3data/r3d:repository/r3d:type          99.39%
# 67         /r3d:re3data/r3d:repository/r3d:versioning          47.42%
# 68                                  Number of Records         100.00%
#
#    2018-02_Re3data
# 0          100.00%
# 1           81.92%
# 2           81.92%
# 3           18.72%
# 4           44.43%
# 5           44.48%
# 6            9.06%
# 7           58.13%
# 8           99.95%
# 9           99.95%
# 10          48.13%
# 11          99.80%
# 12          99.95%
# 13          99.95%
# 14          61.92%
# 15          99.11%
# 16          27.19%
# 17          27.24%
# 18           5.42%
# 19         100.00%
# 20          20.59%
# 21          20.59%
# 22          99.95%
# 23         100.00%
# 24           4.29%
# 25          98.52%
# 26         100.00%
# 27          90.00%
# 28          90.00%
# 29          87.24%
# ..             ...
# 39         100.00%
# 40         100.00%
# 41          29.85%
# 42          29.85%
# 43          29.85%
# 44          82.02%
# 45          95.02%
# 46          87.88%
# 47          87.88%
# 48          99.75%
# 49          99.01%
# 50         100.00%
# 51          66.95%
# 52          86.55%
# 53          27.24%
# 54          99.70%
# 55         100.00%
# 56         100.00%
# 57         100.00%
# 58          39.31%
# 59         100.00%
# 60          83.99%
# 61          70.69%
# 62          99.16%
# 63          99.16%
# 64          28.03%
# 65          28.03%
# 66          99.36%
# 67          47.54%
# 68         100.00%
#
# [69 rows x 3 columns]

# %% [markdown]
# ## Now that the data products are created and combined, we can look at Re3data through time using the Exploration Notebook.

# %% [markdown]
# Create a dataframe of the records in the collection missing a specific element, selectable by dropdown widget

# %%
XPathChoices=list(CombinedXPathCountsDF)
XPathChoices=XPathChoices[2:]
def RecordsMissingXPath(XPathChoice):
    global xPathChoice
    xPathChoice=XPathChoice
    doesntHaveDF=CombinedXPathCountsDF.loc[CombinedXPathCountsDF[xPathChoice] == 0.0]
    doesntHaveDF=doesntHaveDF[['Collection','Record']]
    return doesntHaveDF

w7=interact(RecordsMissingXPath, XPathChoice=XPathChoices) 
display(w7)
# Out:
# <function __main__.RecordsMissingXPath>

# %% [markdown]
# By using the function below, a dropdown can select what element to look at the content for

# %%
XPathChoices=list(CombinedXPathCountsDF)
XPathChoices=XPathChoices[2:]
def ContentAtElement(XPathChoice):
    global CombinedContentAtElementDF
    xPathChoice=XPathChoice
    CombinedContentAtElementDF=CombinedEvaluatedMetadataDF.loc[CombinedEvaluatedMetadataDF.XPath==xPathChoice]
    CombinedContentAtElementDF=CombinedContentAtElementDF[['Collection','Record','Content']]
    distribution=CombinedContentAtElementDF.groupby('Content').size().sort_values(0,False)
    data = CombinedContentAtElementDF.Content.str.replace(':','.')

   # p = Bar(data, 'Content', title="Content Occurance Count", legend=False)

    
    return distribution

interact(ContentAtElement, XPathChoice=XPathChoices)
# Out:
# <function __main__.ContentAtElement>
